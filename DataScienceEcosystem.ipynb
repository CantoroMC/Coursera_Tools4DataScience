# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Data Science Tools and Ecosystem](#toc1_)
#   - [Introduction](#toc1_1_)
#   - [Data Science Languages](#toc1_2_)
#   - [Data Scientists Libraries](#toc1_3_)
#   - [Data Science Tools](#toc1_4_)
#   - [Arithmetic Expression](#toc1_5_)
#     - [Below are a few examples of evaluating arithmetic expressions in Python.](#toc1_5_1_)
#   - [Objectives List](#toc1_6_)
#   - [Author](#toc1_7_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc1_'></a>[Data Science Tools and Ecosystem](#toc0_)

# %% [markdown]
# ## <a id='toc1_1_'></a>[Introduction](#toc0_)
#
# The objective of this Jupyter notebook is to prove my proficiency with the main tools used to develop (R, python + IDEs) and share (git, github) data analysis reviews.
#
# I'm an energy engineer, I was already very familiar with all UNIX tools, ipynbs, git/github, neovim, vscode, python, c++, c, Haskell, _some R_, *markdown*, <span style="color:blue">some **html**</span>, $\LaTeX{}$ ....

# %% [markdown]
# ## <a id='toc1_2_'></a>[Data Science Languages](#toc0_)
#
# Some of the popular languages that Data Scientist use are:
#
# 1. R
# 2. Python
# 3. SQL
# 4. Scala
# 5. Java
# 6. C++
# 7. Julia

# %% [markdown]
# ## <a id='toc1_3_'></a>[Data Scientists Libraries](#toc0_)
#
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. Matplotlib
# 2. Numpy
# 3. scipy
# 4. seaborn
# 5. Pandas
# 6. ggplot2
# 7. scikit-learn
# 8. keras
# 9. TensorFlow
# 10. PyTorch

# %% [markdown]
# ## <a id='toc1_4_'></a>[Data Science Tools](#toc0_)
#
# | Data Science Tools |
# | ------------------ |
# | Jupyter Notebook   |
# | Integrated Developer Environments |
# | Git  |
# | Editor + LSPs |

# %% [markdown]
# ## <a id='toc1_5_'></a>[Arithmetic Expression](#toc0_)
#
# ### <a id='toc1_5_1_'></a>[Below are a few examples of evaluating arithmetic expressions in Python.](#toc0_)

# %%
# This a simple arithmetic expression to mutiply then add integers
# Personal comment: you should not use comment in a nb, but rather a markdown cell, that's the all point of literate programming
(3 * 4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
minutes = 200
hours = minutes / 60

hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## <a id='toc1_6_'></a>[Objectives List](#toc0_)
#
# **Objectives:**
#
# - Jupyter NB as great way to proficiently integrate data analysis and presentation creation
# - Git and open source as powerful tools for continuos improvement
# - IBMs DAX and MAX and IBM Watson Studio
# - Data management, integration & transformation, visualization and model building & deployment.

# %% [markdown]
# ## <a id='toc1_7_'></a>[Author](#toc0_)
#
# Marco C.
